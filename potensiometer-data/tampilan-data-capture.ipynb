# %% [markdown]
# #

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy as scipy
from scipy import optimize
from matplotlib.ticker import AutoMinorLocator
from matplotlib import gridspec
import matplotlib.ticker as ticker
# %matplotlib inline

# %%
# numerical data file
filename1="capture1.txt"
filename2="capture2.txt"
filename3="capture3.txt"
filename4="capture4.txt"
filename5="capture5.txt"
filename6="capture6.txt"

# %%
data1 = np.loadtxt(filename1, delimiter=",")
data2 = np.loadtxt(filename2, delimiter=",")
data3 = np.loadtxt(filename3, delimiter=",")
data4 = np.loadtxt(filename4, delimiter=",")
data5 = np.loadtxt(filename5, delimiter=",")
data6 = np.loadtxt(filename6, delimiter=",")

# %%
data
# Out:
# array([44., 44., 44., ..., 41., 41., 42.])

# %%
fig = plt.figure(figsize=(16,4))
gs = gridspec.GridSpec(1,1)
ax1 = fig.add_subplot(gs[0])
ax1.plot(data1, "r-")
ax1.set_xlim(0,2500)
fig.savefig("data1.png", format="png",dpi=1000)

# %%
fig = plt.figure(figsize=(16,4))
gs = gridspec.GridSpec(1,1)
ax1 = fig.add_subplot(gs[0])
ax1.plot(data2, "g-")
ax1.set_xlim(0,2500)
fig.savefig("data2.png", format="png",dpi=1000)

# %%
fig = plt.figure(figsize=(16,4))
gs = gridspec.GridSpec(1,1)
ax1 = fig.add_subplot(gs[0])
ax1.plot(data3, "b-")
ax1.set_xlim(0,2500)
fig.savefig("data3.png", format="png",dpi=1000)
